# %%
with open ("results_per_tag_1_batch.txt", "r") as myfile:
    data=myfile.readlines()
data=eval(data[0])
data
# Out:
# {'LOC': {'ent_type': {'correct': 400,
#    'incorrect': 18,
#    'partial': 0,
#    'missed': 24,
#    'spurious': 35,
#    'possible': 442,
#    'actual': 453,
#    'precision': 0.8830022075055187,
#    'recall': 0.9049773755656109,
#    'f1': 0.8938547486033519},
#   'partial': {'correct': 396,
#    'incorrect': 0,
#    'partial': 22,
#    'missed': 24,
#    'spurious': 35,
#    'possible': 442,
#    'actual': 453,
#    'precision': 0.8984547461368654,
#    'recall': 0.920814479638009,
#    'f1': 0.9094972067039105},
#   'strict': {'correct': 384,
#    'incorrect': 34,
#    'partial': 0,
#    'missed': 24,
#    'spurious': 35,
#    'possible': 442,
#    'actual': 453,
#    'precision': 0.847682119205298,
#    'recall': 0.8687782805429864,
#    'f1': 0.8581005586592179},
#   'exact': {'correct': 396,
#    'incorrect': 22,
#    'partial': 0,
#    'missed': 24,
#    'spurious': 35,
#    'possible': 442,
#    'actual': 453,
#    'precision': 0.8741721854304636,
#    'recall': 0.8959276018099548,
#    'f1': 0.8849162011173185}},
#  'PER': {'ent_type': {'correct': 1014,
#    'incorrect': 17,
#    'partial': 0,
#    'missed': 119,
#    'spurious': 48,
#    'possible': 1150,
#    'actual': 1079,
#    'precision': 0.9397590361445783,
#    'recall': 0.8817391304347826,
#    'f1': 0.9098250336473754},
#   'partial': {'correct': 1010,
#    'incorrect': 0,
#    'partial': 21,
#    'missed': 119,
#    'spurious': 48,
#    'possible': 1150,
#    'actual': 1079,
#    'precision': 0.9457831325301205,
#    'recall': 0.8873913043478261,
#    'f1': 0.9156572454015254},
#   'strict': {'correct': 999,
#    'incorrect': 32,
#    'partial': 0,
#    'missed': 119,
#    'spurious': 48,
#    'possible': 1150,
#    'actual': 1079,
#    'precision': 0.9258572752548656,
#    'recall': 0.8686956521739131,
#    'f1': 0.8963660834454913},
#   'exact': {'correct': 1010,
#    'incorrect': 21,
#    'partial': 0,
#    'missed': 119,
#    'spurious': 48,
#    'possible': 1150,
#    'actual': 1079,
#    'precision': 0.9360518999073216,
#    'recall': 0.8782608695652174,
#    'f1': 0.9062359802602064}},
#  'ORG': {'ent_type': {'correct': 315,
#    'incorrect': 27,
#    'partial': 0,
#    'missed': 52,
#    'spurious': 30,
#    'possible': 394,
#    'actual': 372,
#    'precision': 0.8467741935483871,
#    'recall': 0.799492385786802,
#    'f1': 0.8224543080939948},
#   'partial': {'correct': 323,
#    'incorrect': 0,
#    'partial': 19,
#    'missed': 52,
#    'spurious': 30,
#    'possible': 394,
#    'actual': 372,
#    'precision': 0.8938172043010753,
#    'recall': 0.8439086294416244,
#    'f1': 0.8681462140992168},
#   'strict': {'correct': 301,
#    'incorrect': 41,
#    'partial': 0,
#    'missed': 52,
#    'spurious': 30,
#    'possible': 394,
#    'actual': 372,
#    'precision': 0.8091397849462365,
#    'recall': 0.7639593908629442,
#    'f1': 0.7859007832898173},
#   'exact': {'correct': 323,
#    'incorrect': 19,
#    'partial': 0,
#    'missed': 52,
#    'spurious': 30,
#    'possible': 394,
#    'actual': 372,
#    'precision': 0.8682795698924731,
#    'recall': 0.8197969543147208,
#    'f1': 0.8433420365535248}},
#  'PROD': {'ent_type': {'correct': 617,
#    'incorrect': 30,
#    'partial': 0,
#    'missed': 42,
#    'spurious': 39,
#    'possible': 689,
#    'actual': 686,
#    'precision': 0.8994169096209913,
#    'recall': 0.895500725689405,
#    'f1': 0.8974545454545456},
#   'partial': {'correct': 629,
#    'incorrect': 0,
#    'partial': 18,
#    'missed': 42,
#    'spurious': 39,
#    'possible': 689,
#    'actual': 686,
#    'precision': 0.9300291545189504,
#    'recall': 0.9259796806966618,
#    'f1': 0.9279999999999999},
#   'strict': {'correct': 607,
#    'incorrect': 40,
#    'partial': 0,
#    'missed': 42,
#    'spurious': 39,
#    'possible': 689,
#    'actual': 686,
#    'precision': 0.8848396501457726,
#    'recall': 0.8809869375907112,
#    'f1': 0.882909090909091},
#   'exact': {'correct': 629,
#    'incorrect': 18,
#    'partial': 0,
#    'missed': 42,
#    'spurious': 39,
#    'possible': 689,
#    'actual': 686,
#    'precision': 0.9169096209912536,
#    'recall': 0.9129172714078374,
#    'f1': 0.9149090909090909}},
#  'WA': {'ent_type': {'correct': 6,
#    'incorrect': 16,
#    'partial': 0,
#    'missed': 8,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 26,
#    'precision': 0.23076923076923078,
#    'recall': 0.2,
#    'f1': 0.21428571428571427},
#   'partial': {'correct': 13,
#    'incorrect': 0,
#    'partial': 9,
#    'missed': 8,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 26,
#    'precision': 0.6730769230769231,
#    'recall': 0.5833333333333334,
#    'f1': 0.6250000000000001},
#   'strict': {'correct': 4,
#    'incorrect': 18,
#    'partial': 0,
#    'missed': 8,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 26,
#    'precision': 0.15384615384615385,
#    'recall': 0.13333333333333333,
#    'f1': 0.14285714285714288},
#   'exact': {'correct': 13,
#    'incorrect': 9,
#    'partial': 0,
#    'missed': 8,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 26,
#    'precision': 0.5,
#    'recall': 0.43333333333333335,
#    'f1': 0.4642857142857143}},
#  'EV': {'ent_type': {'correct': 106,
#    'incorrect': 7,
#    'partial': 0,
#    'missed': 39,
#    'spurious': 44,
#    'possible': 152,
#    'actual': 157,
#    'precision': 0.6751592356687898,
#    'recall': 0.6973684210526315,
#    'f1': 0.686084142394822},
#   'partial': {'correct': 92,
#    'incorrect': 0,
#    'partial': 21,
#    'missed': 39,
#    'spurious': 44,
#    'possible': 152,
#    'actual': 157,
#    'precision': 0.6528662420382165,
#    'recall': 0.6743421052631579,
#    'f1': 0.663430420711974},
#   'strict': {'correct': 91,
#    'incorrect': 22,
#    'partial': 0,
#    'missed': 39,
#    'spurious': 44,
#    'possible': 152,
#    'actual': 157,
#    'precision': 0.5796178343949044,
#    'recall': 0.5986842105263158,
#    'f1': 0.5889967637540453},
#   'exact': {'correct': 92,
#    'incorrect': 21,
#    'partial': 0,
#    'missed': 39,
#    'spurious': 44,
#    'possible': 152,
#    'actual': 157,
#    'precision': 0.5859872611464968,
#    'recall': 0.6052631578947368,
#    'f1': 0.5954692556634305}}}

# %%
data['LOC']['partial']
# Out:
# {'correct': 396,
#  'incorrect': 0,
#  'partial': 22,
#  'missed': 24,
#  'spurious': 35,
#  'possible': 442,
#  'actual': 453,
#  'precision': 0.8984547461368654,
#  'recall': 0.920814479638009,
#  'f1': 0.9094972067039105}

# %%
from operator import itemgetter

temp=dict()
for i in ['LOC', 'PER', 'ORG', 'PROD', 'WA', 'EV']:
    for j in ['partial','exact']:
        temp[(i,j)]=itemgetter('precision','recall','f1')(data[i][j])

# %%
temp
# Out:
# {('LOC', 'partial'): (0.8984547461368654,
#   0.920814479638009,
#   0.9094972067039105),
#  ('LOC', 'exact'): (0.8741721854304636,
#   0.8959276018099548,
#   0.8849162011173185),
#  ('PER', 'partial'): (0.9457831325301205,
#   0.8873913043478261,
#   0.9156572454015254),
#  ('PER', 'exact'): (0.9360518999073216,
#   0.8782608695652174,
#   0.9062359802602064),
#  ('ORG', 'partial'): (0.8938172043010753,
#   0.8439086294416244,
#   0.8681462140992168),
#  ('ORG', 'exact'): (0.8682795698924731,
#   0.8197969543147208,
#   0.8433420365535248),
#  ('PROD', 'partial'): (0.9300291545189504,
#   0.9259796806966618,
#   0.9279999999999999),
#  ('PROD', 'exact'): (0.9169096209912536,
#   0.9129172714078374,
#   0.9149090909090909),
#  ('WA', 'partial'): (0.6730769230769231,
#   0.5833333333333334,
#   0.6250000000000001),
#  ('WA', 'exact'): (0.5, 0.43333333333333335, 0.4642857142857143),
#  ('EV', 'partial'): (0.6528662420382165,
#   0.6743421052631579,
#   0.663430420711974),
#  ('EV', 'exact'): (0.5859872611464968, 0.6052631578947368, 0.5954692556634305)}
