# %%
with open ("results_per_tag_1_batch.txt", "r") as myfile:
    data=myfile.readlines()
data=eval(data[0])
data
# Out:
# {'LOC': {'ent_type': {'correct': 377,
#    'incorrect': 11,
#    'partial': 0,
#    'missed': 54,
#    'spurious': 27,
#    'possible': 442,
#    'actual': 415,
#    'precision': 0.908433734939759,
#    'recall': 0.8529411764705882,
#    'f1': 0.8798133022170361},
#   'partial': {'correct': 367,
#    'incorrect': 0,
#    'partial': 21,
#    'missed': 54,
#    'spurious': 27,
#    'possible': 442,
#    'actual': 415,
#    'precision': 0.9096385542168675,
#    'recall': 0.8540723981900452,
#    'f1': 0.8809801633605601},
#   'strict': {'correct': 361,
#    'incorrect': 27,
#    'partial': 0,
#    'missed': 54,
#    'spurious': 27,
#    'possible': 442,
#    'actual': 415,
#    'precision': 0.8698795180722891,
#    'recall': 0.8167420814479638,
#    'f1': 0.8424737456242707},
#   'exact': {'correct': 367,
#    'incorrect': 21,
#    'partial': 0,
#    'missed': 54,
#    'spurious': 27,
#    'possible': 442,
#    'actual': 415,
#    'precision': 0.8843373493975903,
#    'recall': 0.830316742081448,
#    'f1': 0.8564760793465577}},
#  'PER': {'ent_type': {'correct': 879,
#    'incorrect': 30,
#    'partial': 0,
#    'missed': 241,
#    'spurious': 101,
#    'possible': 1150,
#    'actual': 1010,
#    'precision': 0.8702970297029703,
#    'recall': 0.7643478260869565,
#    'f1': 0.813888888888889},
#   'partial': {'correct': 813,
#    'incorrect': 0,
#    'partial': 96,
#    'missed': 241,
#    'spurious': 101,
#    'possible': 1150,
#    'actual': 1010,
#    'precision': 0.8524752475247525,
#    'recall': 0.7486956521739131,
#    'f1': 0.7972222222222223},
#   'strict': {'correct': 787,
#    'incorrect': 122,
#    'partial': 0,
#    'missed': 241,
#    'spurious': 101,
#    'possible': 1150,
#    'actual': 1010,
#    'precision': 0.7792079207920792,
#    'recall': 0.6843478260869565,
#    'f1': 0.7287037037037036},
#   'exact': {'correct': 813,
#    'incorrect': 96,
#    'partial': 0,
#    'missed': 241,
#    'spurious': 101,
#    'possible': 1150,
#    'actual': 1010,
#    'precision': 0.804950495049505,
#    'recall': 0.7069565217391305,
#    'f1': 0.7527777777777778}},
#  'ORG': {'ent_type': {'correct': 207,
#    'incorrect': 59,
#    'partial': 0,
#    'missed': 128,
#    'spurious': 45,
#    'possible': 394,
#    'actual': 311,
#    'precision': 0.6655948553054662,
#    'recall': 0.5253807106598984,
#    'f1': 0.5872340425531914},
#   'partial': {'correct': 229,
#    'incorrect': 0,
#    'partial': 37,
#    'missed': 128,
#    'spurious': 45,
#    'possible': 394,
#    'actual': 311,
#    'precision': 0.7958199356913184,
#    'recall': 0.6281725888324873,
#    'f1': 0.7021276595744681},
#   'strict': {'correct': 195,
#    'incorrect': 71,
#    'partial': 0,
#    'missed': 128,
#    'spurious': 45,
#    'possible': 394,
#    'actual': 311,
#    'precision': 0.6270096463022508,
#    'recall': 0.4949238578680203,
#    'f1': 0.553191489361702},
#   'exact': {'correct': 229,
#    'incorrect': 37,
#    'partial': 0,
#    'missed': 128,
#    'spurious': 45,
#    'possible': 394,
#    'actual': 311,
#    'precision': 0.7363344051446945,
#    'recall': 0.5812182741116751,
#    'f1': 0.649645390070922}},
#  'PROD': {'ent_type': {'correct': 533,
#    'incorrect': 24,
#    'partial': 0,
#    'missed': 132,
#    'spurious': 77,
#    'possible': 689,
#    'actual': 634,
#    'precision': 0.8406940063091483,
#    'recall': 0.7735849056603774,
#    'f1': 0.8057445200302342},
#   'partial': {'correct': 526,
#    'incorrect': 0,
#    'partial': 31,
#    'missed': 132,
#    'spurious': 77,
#    'possible': 689,
#    'actual': 634,
#    'precision': 0.8541009463722398,
#    'recall': 0.785921625544267,
#    'f1': 0.8185941043083902},
#   'strict': {'correct': 510,
#    'incorrect': 47,
#    'partial': 0,
#    'missed': 132,
#    'spurious': 77,
#    'possible': 689,
#    'actual': 634,
#    'precision': 0.804416403785489,
#    'recall': 0.7402031930333817,
#    'f1': 0.7709750566893423},
#   'exact': {'correct': 526,
#    'incorrect': 31,
#    'partial': 0,
#    'missed': 132,
#    'spurious': 77,
#    'possible': 689,
#    'actual': 634,
#    'precision': 0.8296529968454258,
#    'recall': 0.7634252539912917,
#    'f1': 0.7951625094482236}},
#  'WA': {'ent_type': {'correct': 10,
#    'incorrect': 8,
#    'partial': 0,
#    'missed': 12,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 22,
#    'precision': 0.45454545454545453,
#    'recall': 0.3333333333333333,
#    'f1': 0.3846153846153846},
#   'partial': {'correct': 12,
#    'incorrect': 0,
#    'partial': 6,
#    'missed': 12,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 22,
#    'precision': 0.6818181818181818,
#    'recall': 0.5,
#    'f1': 0.576923076923077},
#   'strict': {'correct': 7,
#    'incorrect': 11,
#    'partial': 0,
#    'missed': 12,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 22,
#    'precision': 0.3181818181818182,
#    'recall': 0.23333333333333334,
#    'f1': 0.2692307692307693},
#   'exact': {'correct': 12,
#    'incorrect': 6,
#    'partial': 0,
#    'missed': 12,
#    'spurious': 4,
#    'possible': 30,
#    'actual': 22,
#    'precision': 0.5454545454545454,
#    'recall': 0.4,
#    'f1': 0.4615384615384615}},
#  'EV': {'ent_type': {'correct': 91,
#    'incorrect': 7,
#    'partial': 0,
#    'missed': 54,
#    'spurious': 32,
#    'possible': 152,
#    'actual': 130,
#    'precision': 0.7,
#    'recall': 0.5986842105263158,
#    'f1': 0.6453900709219859},
#   'partial': {'correct': 81,
#    'incorrect': 0,
#    'partial': 17,
#    'missed': 54,
#    'spurious': 32,
#    'possible': 152,
#    'actual': 130,
#    'precision': 0.6884615384615385,
#    'recall': 0.5888157894736842,
#    'f1': 0.6347517730496454},
#   'strict': {'correct': 78,
#    'incorrect': 20,
#    'partial': 0,
#    'missed': 54,
#    'spurious': 32,
#    'possible': 152,
#    'actual': 130,
#    'precision': 0.6,
#    'recall': 0.5131578947368421,
#    'f1': 0.5531914893617021},
#   'exact': {'correct': 81,
#    'incorrect': 17,
#    'partial': 0,
#    'missed': 54,
#    'spurious': 32,
#    'possible': 152,
#    'actual': 130,
#    'precision': 0.6230769230769231,
#    'recall': 0.5328947368421053,
#    'f1': 0.5744680851063829}}}

# %%
data['LOC']['partial']
# Out:
# {'correct': 367,
#  'incorrect': 0,
#  'partial': 21,
#  'missed': 54,
#  'spurious': 27,
#  'possible': 442,
#  'actual': 415,
#  'precision': 0.9096385542168675,
#  'recall': 0.8540723981900452,
#  'f1': 0.8809801633605601}

# %%
from operator import itemgetter

temp=dict()
for i in ['LOC', 'PER', 'ORG', 'PROD', 'WA', 'EV']:
    for j in ['partial','exact']:
        temp[(i,j)]=itemgetter('precision','recall','f1')(data[i][j])

# %%
temp
# Out:
# {('LOC', 'partial'): (0.9096385542168675,
#   0.8540723981900452,
#   0.8809801633605601),
#  ('LOC', 'exact'): (0.8843373493975903, 0.830316742081448, 0.8564760793465577),
#  ('PER', 'partial'): (0.8524752475247525,
#   0.7486956521739131,
#   0.7972222222222223),
#  ('PER', 'exact'): (0.804950495049505, 0.7069565217391305, 0.7527777777777778),
#  ('ORG', 'partial'): (0.7958199356913184,
#   0.6281725888324873,
#   0.7021276595744681),
#  ('ORG', 'exact'): (0.7363344051446945, 0.5812182741116751, 0.649645390070922),
#  ('PROD', 'partial'): (0.8541009463722398,
#   0.785921625544267,
#   0.8185941043083902),
#  ('PROD', 'exact'): (0.8296529968454258,
#   0.7634252539912917,
#   0.7951625094482236),
#  ('WA', 'partial'): (0.6818181818181818, 0.5, 0.576923076923077),
#  ('WA', 'exact'): (0.5454545454545454, 0.4, 0.4615384615384615),
#  ('EV', 'partial'): (0.6884615384615385,
#   0.5888157894736842,
#   0.6347517730496454),
#  ('EV', 'exact'): (0.6230769230769231, 0.5328947368421053, 0.5744680851063829)}
