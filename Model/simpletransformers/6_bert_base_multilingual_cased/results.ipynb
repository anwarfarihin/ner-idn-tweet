# %%
with open ("results_per_tag_1_batch.txt", "r") as myfile:
    data=myfile.readlines()
data=eval(data[0])
data
# Out:
# {'LOC': {'ent_type': {'correct': 399,
#    'incorrect': 11,
#    'partial': 0,
#    'missed': 32,
#    'spurious': 21,
#    'possible': 442,
#    'actual': 431,
#    'precision': 0.925754060324826,
#    'recall': 0.9027149321266968,
#    'f1': 0.9140893470790379},
#   'partial': {'correct': 387,
#    'incorrect': 0,
#    'partial': 23,
#    'missed': 32,
#    'spurious': 21,
#    'possible': 442,
#    'actual': 431,
#    'precision': 0.9245939675174014,
#    'recall': 0.9015837104072398,
#    'f1': 0.9129438717067584},
#   'strict': {'correct': 383,
#    'incorrect': 27,
#    'partial': 0,
#    'missed': 32,
#    'spurious': 21,
#    'possible': 442,
#    'actual': 431,
#    'precision': 0.888631090487239,
#    'recall': 0.8665158371040724,
#    'f1': 0.877434135166094},
#   'exact': {'correct': 387,
#    'incorrect': 23,
#    'partial': 0,
#    'missed': 32,
#    'spurious': 21,
#    'possible': 442,
#    'actual': 431,
#    'precision': 0.8979118329466357,
#    'recall': 0.8755656108597285,
#    'f1': 0.8865979381443299}},
#  'PER': {'ent_type': {'correct': 957,
#    'incorrect': 15,
#    'partial': 0,
#    'missed': 178,
#    'spurious': 26,
#    'possible': 1150,
#    'actual': 998,
#    'precision': 0.9589178356713427,
#    'recall': 0.8321739130434782,
#    'f1': 0.8910614525139664},
#   'partial': {'correct': 946,
#    'incorrect': 0,
#    'partial': 26,
#    'missed': 178,
#    'spurious': 26,
#    'possible': 1150,
#    'actual': 998,
#    'precision': 0.9609218436873748,
#    'recall': 0.8339130434782609,
#    'f1': 0.8929236499068901},
#   'strict': {'correct': 934,
#    'incorrect': 38,
#    'partial': 0,
#    'missed': 178,
#    'spurious': 26,
#    'possible': 1150,
#    'actual': 998,
#    'precision': 0.935871743486974,
#    'recall': 0.8121739130434783,
#    'f1': 0.8696461824953445},
#   'exact': {'correct': 946,
#    'incorrect': 26,
#    'partial': 0,
#    'missed': 178,
#    'spurious': 26,
#    'possible': 1150,
#    'actual': 998,
#    'precision': 0.9478957915831663,
#    'recall': 0.8226086956521739,
#    'f1': 0.8808193668528863}},
#  'ORG': {'ent_type': {'correct': 297,
#    'incorrect': 37,
#    'partial': 0,
#    'missed': 60,
#    'spurious': 26,
#    'possible': 394,
#    'actual': 360,
#    'precision': 0.825,
#    'recall': 0.7538071065989848,
#    'f1': 0.7877984084880637},
#   'partial': {'correct': 310,
#    'incorrect': 0,
#    'partial': 24,
#    'missed': 60,
#    'spurious': 26,
#    'possible': 394,
#    'actual': 360,
#    'precision': 0.8944444444444445,
#    'recall': 0.817258883248731,
#    'f1': 0.8541114058355438},
#   'strict': {'correct': 278,
#    'incorrect': 56,
#    'partial': 0,
#    'missed': 60,
#    'spurious': 26,
#    'possible': 394,
#    'actual': 360,
#    'precision': 0.7722222222222223,
#    'recall': 0.7055837563451777,
#    'f1': 0.7374005305039787},
#   'exact': {'correct': 310,
#    'incorrect': 24,
#    'partial': 0,
#    'missed': 60,
#    'spurious': 26,
#    'possible': 394,
#    'actual': 360,
#    'precision': 0.8611111111111112,
#    'recall': 0.7868020304568528,
#    'f1': 0.8222811671087533}},
#  'PROD': {'ent_type': {'correct': 582,
#    'incorrect': 17,
#    'partial': 0,
#    'missed': 90,
#    'spurious': 28,
#    'possible': 689,
#    'actual': 627,
#    'precision': 0.9282296650717703,
#    'recall': 0.8447024673439768,
#    'f1': 0.884498480243161},
#   'partial': {'correct': 574,
#    'incorrect': 0,
#    'partial': 25,
#    'missed': 90,
#    'spurious': 28,
#    'possible': 689,
#    'actual': 627,
#    'precision': 0.9354066985645934,
#    'recall': 0.851233671988389,
#    'f1': 0.8913373860182371},
#   'strict': {'correct': 563,
#    'incorrect': 36,
#    'partial': 0,
#    'missed': 90,
#    'spurious': 28,
#    'possible': 689,
#    'actual': 627,
#    'precision': 0.89792663476874,
#    'recall': 0.8171262699564587,
#    'f1': 0.8556231003039513},
#   'exact': {'correct': 574,
#    'incorrect': 25,
#    'partial': 0,
#    'missed': 90,
#    'spurious': 28,
#    'possible': 689,
#    'actual': 627,
#    'precision': 0.9154704944178629,
#    'recall': 0.8330914368650217,
#    'f1': 0.8723404255319149}},
#  'WA': {'ent_type': {'correct': 9,
#    'incorrect': 12,
#    'partial': 0,
#    'missed': 9,
#    'spurious': 0,
#    'possible': 30,
#    'actual': 21,
#    'precision': 0.42857142857142855,
#    'recall': 0.3,
#    'f1': 0.3529411764705882},
#   'partial': {'correct': 15,
#    'incorrect': 0,
#    'partial': 6,
#    'missed': 9,
#    'spurious': 0,
#    'possible': 30,
#    'actual': 21,
#    'precision': 0.8571428571428571,
#    'recall': 0.6,
#    'f1': 0.7058823529411764},
#   'strict': {'correct': 7,
#    'incorrect': 14,
#    'partial': 0,
#    'missed': 9,
#    'spurious': 0,
#    'possible': 30,
#    'actual': 21,
#    'precision': 0.3333333333333333,
#    'recall': 0.23333333333333334,
#    'f1': 0.27450980392156865},
#   'exact': {'correct': 15,
#    'incorrect': 6,
#    'partial': 0,
#    'missed': 9,
#    'spurious': 0,
#    'possible': 30,
#    'actual': 21,
#    'precision': 0.7142857142857143,
#    'recall': 0.5,
#    'f1': 0.588235294117647}},
#  'EV': {'ent_type': {'correct': 92,
#    'incorrect': 8,
#    'partial': 0,
#    'missed': 52,
#    'spurious': 26,
#    'possible': 152,
#    'actual': 126,
#    'precision': 0.7301587301587301,
#    'recall': 0.6052631578947368,
#    'f1': 0.6618705035971223},
#   'partial': {'correct': 83,
#    'incorrect': 0,
#    'partial': 17,
#    'missed': 52,
#    'spurious': 26,
#    'possible': 152,
#    'actual': 126,
#    'precision': 0.7261904761904762,
#    'recall': 0.6019736842105263,
#    'f1': 0.658273381294964},
#   'strict': {'correct': 82,
#    'incorrect': 18,
#    'partial': 0,
#    'missed': 52,
#    'spurious': 26,
#    'possible': 152,
#    'actual': 126,
#    'precision': 0.6507936507936508,
#    'recall': 0.5394736842105263,
#    'f1': 0.5899280575539567},
#   'exact': {'correct': 83,
#    'incorrect': 17,
#    'partial': 0,
#    'missed': 52,
#    'spurious': 26,
#    'possible': 152,
#    'actual': 126,
#    'precision': 0.6587301587301587,
#    'recall': 0.5460526315789473,
#    'f1': 0.5971223021582734}}}

# %%
data['LOC']['partial']
# Out:
# {'correct': 387,
#  'incorrect': 0,
#  'partial': 23,
#  'missed': 32,
#  'spurious': 21,
#  'possible': 442,
#  'actual': 431,
#  'precision': 0.9245939675174014,
#  'recall': 0.9015837104072398,
#  'f1': 0.9129438717067584}

# %%
from operator import itemgetter

temp=dict()
for i in ['LOC', 'PER', 'ORG', 'PROD', 'WA', 'EV']:
    for j in ['partial','exact']:
        temp[(i,j)]=itemgetter('precision','recall','f1')(data[i][j])

# %%
temp
# Out:
# {('LOC', 'partial'): (0.9245939675174014,
#   0.9015837104072398,
#   0.9129438717067584),
#  ('LOC', 'exact'): (0.8979118329466357,
#   0.8755656108597285,
#   0.8865979381443299),
#  ('PER', 'partial'): (0.9609218436873748,
#   0.8339130434782609,
#   0.8929236499068901),
#  ('PER', 'exact'): (0.9478957915831663,
#   0.8226086956521739,
#   0.8808193668528863),
#  ('ORG', 'partial'): (0.8944444444444445,
#   0.817258883248731,
#   0.8541114058355438),
#  ('ORG', 'exact'): (0.8611111111111112,
#   0.7868020304568528,
#   0.8222811671087533),
#  ('PROD', 'partial'): (0.9354066985645934,
#   0.851233671988389,
#   0.8913373860182371),
#  ('PROD', 'exact'): (0.9154704944178629,
#   0.8330914368650217,
#   0.8723404255319149),
#  ('WA', 'partial'): (0.8571428571428571, 0.6, 0.7058823529411764),
#  ('WA', 'exact'): (0.7142857142857143, 0.5, 0.588235294117647),
#  ('EV', 'partial'): (0.7261904761904762,
#   0.6019736842105263,
#   0.658273381294964),
#  ('EV', 'exact'): (0.6587301587301587, 0.5460526315789473, 0.5971223021582734)}
