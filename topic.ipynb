# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('./nercrawler (1).xlsx')

# %%
subjs=['prabowo',
 'aniesbaswedan',
 'khofifah',
 'nerpendidikan',
 'ganjarpranowo',
 'borobudur',
 'belanjaramadhan',
 'muhaiminiskandar',
 'ecommerce',
 'vaksin',
 'gajibonus',
 'megawati',
 'puanmaharani',
 'thr',
 'liburan',
 'ridwankamil',
 'ngabuburit',
 'nerolahraga',
 'nerkesehatan',
 'nersocmed',
 'beramal',
 'hiburandirumah',
 'bukber',
 'airlangga',
 'hiburan',
 'agusyudhoyono',
 'nerinternet',
 'wiranto',
 'pajak',
 'sandang',
 'mobileonlinegame',
 'peralatanpribadi',
 'bubbledrink',
 'zulkiflihasan',
 'restoran',
 'jasa',
 'streaminglagu',
 'konsumsitakjil',
 'miras',
 'savingbehavior',
 'nerbencanaalam',
 'layanangojek',
 'tehkemasan',
 'comfortfoodpuasa',
 'bahanpangan',
 'inflasi',
 'transportasi',
 'pajakimpor',
 'suryapaloh',
 'lowongankerja',
 'alatsolat',
 'kumpulkeluarga',
 'pengangguran',
 'ahmadsyaikhu',
 'makananramadan',
 'tokocoklat',
 'sirup',
 'penghasilanpasif',
 'gratisongkir',
 'suharsomonoarfa',
 'kangenbioskop',
 'uangdigital',
 'ibadahdiluar',
 'brandkecantikan3',
 'bankindonesia',
 'restorangeprek',
 'perumahan',
 'pakaianmuslim',
 'brandkecantikan2',
 'pendidikan',
 'bali',
 'aplikasidating',
 'kesehatan',
 'kreditproperti',
 'rumahtangga',
 'kopikekinian',
 'produkkredit',
 'kreditgadget',
 'mandalika',
 'danautoba',
 'hamperslebaran',
 'susububuk',
 'mudik',
 'mieinstanbag',
 'pph',
 'minumantenaganoncair',
 'investasi',
 'investasikripto',
 'kreditkendaraan',
 'tokoeskrim',
 'perusahaanekspedisi',
 'restoranfastfood',
 'labuanbajo',
 'perilakukredit',
 'usahaturun',
 'yusrilihza',
 'kendaraanniaga',
 'motormatic',
 'minumansaribuah',
 'pajakkendaraan',
 'layananpesanantar',
 'motorsport',
 'minumanbersoda',
 'airlines',
 'isp',
 'kpr',
 'sabunmandi',
 'brandkecantikan',
 'lembagazakat',
 'crowdfunding',
 'kartukredit',
 'cafe',
 'coklatbatangan',
 'sarung',
 'situsonlinereservasihotel',
 'elearndevice',
 'mobillistrik',
 'mobilebanking']

# %%
df[df.Subject in subjs]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4476/4291756509.py in <module>
# ----> 1 df[df.Subject in subjs].any()
#
# d:\Drive\KULEEAH\Semester 8\TA Farihin\env\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1533     def __nonzero__(self):
#    1534         raise ValueError(
# -> 1535             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1536             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1537         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
